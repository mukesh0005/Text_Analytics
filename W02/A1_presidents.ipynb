# %% [markdown]
# ### Scarping President data

# %% [markdown]
# - Import libraries

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from webdriver_manager.firefox import GeckoDriverManager
import re
import dateparser

# %% [markdown]
# - Initializing the driver and collect HTML content of the page using Beautiful soup

# %%
driver = webdriver.Firefox()

url = "https://www.britannica.com/topic/Presidents-of-the-United-States-1846696"
driver.get(url)
driver.implicitly_wait(10)

page_source = driver.page_source

presidents = pd.read_html(page_source)[0]

# %%
presidents.head()
# Out:
#   Unnamed: 0 no.          president birthplace        political party  \
# 0        NaN   1  George Washington        Va.             Federalist
# 1        NaN   2         John Adams      Mass.             Federalist
# 2        NaN   3   Thomas Jefferson        Va.  Democratic-Republican
# 3        NaN   4      James Madison        Va.  Democratic-Republican
# 4        NaN   5       James Monroe        Va.  Democratic-Republican
#
#         term
# 0    1789–97
# 1  1797–1801
# 2    1801–09
# 3    1809–17
# 4    1817–25

# %% [markdown]
# - Creating Function to convert term into start and end year

# %%
presidents['term'] = presidents.apply(lambda row: re.sub(r"[^\d–]", "", row['term']), axis=1) # replace any non-digit before dash with blank

# first, split the string in the term column using dash as delimiter - store this in new column called 'from'
presidents['start_year'] = presidents['term'].apply(lambda x: x.split("–")[0]) 

# if there is no end year, then the end year is the same as the start year, otherwise get the second element of the split string, this is the end year of the term
presidents['end_year'] = presidents['term'].apply(lambda x: x.split("–")[0] if len(x.split("–"))==1 else x.split("–")[1]) 

# if the end year is only two digits, then add the first two digits of the start year to the end year
presidents['end_year'] = presidents.apply(lambda row:  row['start_year'][:2]+row['end_year'] if len(row['end_year'])==2 else row['end_year'], axis=1) 

presidents
# Out:
#                  Unnamed: 0                      no.                president  \
# 0                       NaN                        1        George Washington
# 1                       NaN                        2               John Adams
# 2                       NaN                        3         Thomas Jefferson
# 3                       NaN                        4            James Madison
# 4                       NaN                        5             James Monroe
# 5                       NaN                        6        John Quincy Adams
# 6                       NaN                        7           Andrew Jackson
# 7                       NaN                        8         Martin Van Buren
# 8                       NaN                        9   William Henry Harrison
# 9                       NaN                       10               John Tyler
# 10                      NaN                       11            James K. Polk
# 11                      NaN                       12           Zachary Taylor
# 12                      NaN                       13         Millard Fillmore
# 13                      NaN                       14          Franklin Pierce
# 14                      NaN                       15           James Buchanan
# 15                      NaN                       16          Abraham Lincoln
# 16                      NaN                       17           Andrew Johnson
# 17                      NaN                       18         Ulysses S. Grant
# 18                      NaN                       19      Rutherford B. Hayes
# 19                      NaN                       20        James A. Garfield
# 20                      NaN                       21        Chester A. Arthur
# 21                      NaN                       22         Grover Cleveland
# 22                      NaN                       23        Benjamin Harrison
# 23                      NaN                       24         Grover Cleveland
# 24                      NaN                       25         William McKinley
# 25                      NaN                       26       Theodore Roosevelt
# 26                      NaN                       27      William Howard Taft
# 27                      NaN                       28           Woodrow Wilson
# 28                      NaN                       29        Warren G. Harding
# 29                      NaN                       30          Calvin Coolidge
# 30                      NaN                       31           Herbert Hoover
# 31                      NaN                       32    Franklin D. Roosevelt
# 32                      NaN                       33          Harry S. Truman
# 33                      NaN                       34     Dwight D. Eisenhower
# 34                      NaN                       35          John F. Kennedy
# 35                      NaN                       36        Lyndon B. Johnson
# 36                      NaN                       37         Richard M. Nixon
# 37                      NaN                       38           Gerald R. Ford
# 38                      NaN                       39             Jimmy Carter
# 39                      NaN                       40            Ronald Reagan
# 40                      NaN                       41              George Bush
# 41                      NaN                       42             Bill Clinton
# 42                      NaN                       43           George W. Bush
# 43                      NaN                       44             Barack Obama
# 44                      NaN                       45             Donald Trump
# 45                      NaN                       46                Joe Biden
# 46         *Died in office.         *Died in office.         *Died in office.
# 47  **Resigned from office.  **Resigned from office.  **Resigned from office.
#
#                  birthplace          political party       term start_year  \
# 0                       Va.               Federalist    1789–97       1789
# 1                     Mass.               Federalist  1797–1801       1797
# 2                       Va.    Democratic-Republican    1801–09       1801
# 3                       Va.    Democratic-Republican    1809–17       1809
# 4                       Va.    Democratic-Republican    1817–25       1817
# 5                     Mass.      National Republican    1825–29       1825
# 6                      S.C.               Democratic    1829–37       1829
# 7                      N.Y.               Democratic    1837–41       1837
# 8                       Va.                     Whig       1841       1841
# 9                       Va.                     Whig    1841–45       1841
# 10                     N.C.               Democratic    1845–49       1845
# 11                      Va.                     Whig    1849–50       1849
# 12                     N.Y.                     Whig    1850–53       1850
# 13                     N.H.               Democratic    1853–57       1853
# 14                      Pa.               Democratic    1857–61       1857
# 15                      Ky.               Republican    1861–65       1861
# 16                     N.C.       Democratic (Union)    1865–69       1865
# 17                     Ohio               Republican    1869–77       1869
# 18                     Ohio               Republican    1877–81       1877
# 19                     Ohio               Republican       1881       1881
# 20                      Vt.               Republican    1881–85       1881
# 21                     N.J.               Democratic    1885–89       1885
# 22                     Ohio               Republican    1889–93       1889
# 23                     N.J.               Democratic    1893–97       1893
# 24                     Ohio               Republican  1897–1901       1897
# 25                     N.Y.               Republican    1901–09       1901
# 26                     Ohio               Republican    1909–13       1909
# 27                      Va.               Democratic    1913–21       1913
# 28                     Ohio               Republican    1921–23       1921
# 29                      Vt.               Republican    1923–29       1923
# 30                     Iowa               Republican    1929–33       1929
# 31                     N.Y.               Democratic    1933–45       1933
# 32                      Mo.               Democratic    1945–53       1945
# 33                    Texas               Republican    1953–61       1953
# 34                    Mass.               Democratic    1961–63       1961
# 35                    Texas               Democratic    1963–69       1963
# 36                   Calif.               Republican    1969–74       1969
# 37                     Neb.               Republican    1974–77       1974
# 38                      Ga.               Democratic    1977–81       1977
# 39                     Ill.               Republican    1981–89       1981
# 40                    Mass.               Republican    1989–93       1989
# 41                     Ark.               Democratic  1993–2001       1993
# 42                    Conn.               Republican    2001–09       2001
# 43                   Hawaii               Democratic    2009–17       2009
# 44                     N.Y.               Republican    2017–21       2017
# 45                      Pa.               Democratic      2021–       2021
# 46         *Died in office.         *Died in office.
# 47  **Resigned from office.  **Resigned from office.
#
#    end_year
# 0      1797
# 1      1801
# 2      1809
# 3      1817
# 4      1825
# 5      1829
# 6      1837
# 7      1841
# 8      1841
# 9      1845
# 10     1849
# 11     1850
# 12     1853
# 13     1857
# 14     1861
# 15     1865
# 16     1869
# 17     1877
# 18     1881
# 19     1881
# 20     1885
# 21     1889
# 22     1893
# 23     1897
# 24     1901
# 25     1909
# 26     1913
# 27     1921
# 28     1923
# 29     1929
# 30     1933
# 31     1945
# 32     1953
# 33     1961
# 34     1963
# 35     1969
# 36     1974
# 37     1977
# 38     1981
# 39     1989
# 40     1993
# 41     2001
# 42     2009
# 43     2017
# 44     2021
# 45
# 46
# 47

# %% [markdown]
# - Appending the start year and End year to presidents dataframe

# %% [markdown]
# ### Converting it to a csv and saving file

# %%
presidents.to_csv("presidents.csv", encoding="utf-8",quotechar="'",index=False)

# %%
presidents.rename(columns={'president':'name'}, inplace=True)

# %%
presidents.head()
# Out:
#   Unnamed: 0 no.               name birthplace        political party  \
# 0        NaN   1  George Washington        Va.             Federalist
# 1        NaN   2         John Adams      Mass.             Federalist
# 2        NaN   3   Thomas Jefferson        Va.  Democratic-Republican
# 3        NaN   4      James Madison        Va.  Democratic-Republican
# 4        NaN   5       James Monroe        Va.  Democratic-Republican
#
#         term start_year end_year
# 0    1789–97       1789     1797
# 1  1797–1801       1797     1801
# 2    1801–09       1801     1809
# 3    1809–17       1809     1817
# 4    1817–25       1817     1825

# %% [markdown]
# ### Loading presidental speeches from the csv file saved

# %%
speechs = pd.read_csv("presidential_speeches.csv", encoding="utf-8",quotechar="'")
speechs.shape
# Out:
# (928, 5)

# %% [markdown]
# ### Matching the names of both the csv files

# %%
import difflib

# %%
name_match ={}
for name in presidents['name']:
        closest_match = difflib.get_close_matches(name, speechs['name'], n=1)
        if closest_match:
                name_match[name] = closest_match[0]

presidents['name_match'] = presidents['name'].map(name_match)

# %% [markdown]
# ### Merging both the csv's.

# %%
merged_df = presidents.merge(speechs, left_on='name_match', right_on='name', how='inner')

# %%
merged_df[:3]
# Out:
#   Unnamed: 0 no.             name_x birthplace political party     term  \
# 0        NaN   1  George Washington        Va.      Federalist  1789–97
# 1        NaN   1  George Washington        Va.      Federalist  1789–97
# 2        NaN   1  George Washington        Va.      Federalist  1789–97
#
#   start_year end_year      name_match          name_y  \
# 0       1789     1797  George W. Bush  George W. Bush
# 1       1789     1797  George W. Bush  George W. Bush
# 2       1789     1797  George W. Bush  George W. Bush
#
#                                                title               date  \
# 0   January 15, 2009: Farewell Address to the Nation   January 15, 2009
# 1           January 12, 2009: Final Press Conference   January 12, 2009
# 2  December 19, 2008: Remarks on Plan to Assist A...  December 19, 2008
#
#                                                 info  \
# 0  President George W. Bush gives his farewell ad...
# 1  In his last press conference as president, Pre...
# 2  From the White House's Roosevelt Room, Preside...
#
#                                               speech
# 0     Fellow citizens:\r For eight years, it has ...
# 1     THE PRESIDENT: Thank you. Tapper. We have b...
# 2     Good morning. For years, America's automake...

# %% [markdown]
# ### Collecting all the required information from the merged dataframe and converting it into a new csv for analysis

# %%
president_speech_df = pd.DataFrame()

# %%
president_speech_df['Name'] = merged_df['name_x']
president_speech_df['Political Party'] = merged_df['political party']
president_speech_df['Speech'] = merged_df['speech']
president_speech_df['Date'] = merged_df['date']
president_speech_df['Start_year'] = merged_df['start_year']
president_speech_df['End_year'] = merged_df['end_year']
president_speech_df['Title'] = merged_df['title']

# %%
president_speech_df.to_csv("A1_data_presidents.csv", encoding="utf-8",quotechar="'",index=False)

# %%
president_speech_df
# Out:
#                    Name Political Party  \
# 0     George Washington      Federalist
# 1     George Washington      Federalist
# 2     George Washington      Federalist
# 3     George Washington      Federalist
# 4     George Washington      Federalist
# ...                 ...             ...
# 1008          Joe Biden      Democratic
# 1009          Joe Biden      Democratic
# 1010          Joe Biden      Democratic
# 1011          Joe Biden      Democratic
# 1012          Joe Biden      Democratic
#
#                                                  Speech               Date  \
# 0        Fellow citizens:\r For eight years, it has ...   January 15, 2009
# 1        THE PRESIDENT: Thank you. Tapper. We have b...   January 12, 2009
# 2        Good morning. For years, America's automake...  December 19, 2008
# 3        Thank you very much. Please be seated. Than...  November 13, 2008
# 4        A short time ago, the House of Representati...   October 03, 2008
# ...                                                 ...                ...
# 1008     \r THE PRESIDENT: Thank you. (Applause.) Th...     April 28, 2021
# 1009     THE PRESIDENT: Thank you. (Applause.) (Inau...     March 31, 2021
# 1010     THE PRESIDENT: Please, please sit down. Tha...     March 25, 2021
# 1011     THE PRESIDENT: Good evening, my fellow Amer...     March 11, 2021
# 1012     Chief Justice Roberts, Vice President Harri...   January 20, 2021
#
#      Start_year End_year                                              Title
# 0          1789     1797   January 15, 2009: Farewell Address to the Nation
# 1          1789     1797           January 12, 2009: Final Press Conference
# 2          1789     1797  December 19, 2008: Remarks on Plan to Assist A...
# 3          1789     1797  November 13, 2008: Speech on Financial Markets...
# 4          1789     1797  October 3, 2008: Remarks on Emergency Economic...
# ...         ...      ...                                                ...
# 1008       2021           April 28, 2021: Address to Joint Session of Co...
# 1009       2021           March 31, 2021: Announcing the American Jobs Plan
# 1010       2021                      March 25, 2021: First Press Conference
# 1011       2021           March 11, 2021: Remarks on the Anniversary of ...
# 1012       2021                         January 20, 2021: Inaugural Address
#
# [1013 rows x 7 columns]
