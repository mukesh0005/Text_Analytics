# %% [markdown]
# ## Airline Sentimental Analysis

# %% [markdown]
# - Load libraries

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from matplotlib import pyplot as plt

from nltk.tokenize import TweetTokenizer

from nltk.sentiment.vader import SentimentIntensityAnalyzer

from textblob import TextBlob
import seaborn as sns

# %%
# read in the data 
df = pd.read_csv('data/A_tweets.csv') 
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
tokenizer = TweetTokenizer()

def clear_text(text):
    # tokenize the text
    # nltk.download('punkt') # uncomment if you need to download the punkt package
    tokens = tokenizer.tokenize(text)
    
    # remove all tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    
    # make lowercase
    tokens = [word.lower() for word in tokens]

    # remove all tokens that are only one character
    tokens = [word for word in tokens if len(word) > 1]

    return ' '.join(tokens)

df['clean_text']=df.text.apply(lambda x: clear_text(x))   
df['hashtags'] = df.text.apply(lambda text: re.findall(r"#(\w+)", text))
df['handles'] = df.text.apply(lambda text: re.findall(r"@(\w+)", text))

# %%
df.columns
# Out:
# Index(['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence',
#        'negativereason', 'negativereason_confidence', 'airline',
#        'airline_sentiment_gold', 'name', 'negativereason_gold',
#        'retweet_count', 'text', 'tweet_coord', 'tweet_created',
#        'tweet_location', 'user_timezone', 'clean_text', 'hashtags', 'handles'],
#       dtype='object')

# %%
df = df.drop(columns=["tweet_id", "name", "retweet_count",'airline_sentiment_confidence',
       'negativereason', 'negativereason_confidence','airline_sentiment_gold', 'negativereason_gold',
       'tweet_coord', 'tweet_created','tweet_location', 'user_timezone']) # though we could use these columns for other analysis, for this analysis we will not

# %%
df.head(5)
# Out:
#   airline_sentiment         airline  \
# 0           neutral  Virgin America
# 1          positive  Virgin America
# 2           neutral  Virgin America
# 3          negative  Virgin America
# 4          negative  Virgin America
#
#                                                 text  \
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...
#
#                                           clean_text hashtags  \
# 0                                          what said       []
# 1     plus added commercials to the experience tacky       []
# 2          today must mean need to take another trip       []
# 3  really aggressive to blast obnoxious entertain...       []
# 4                  and really big bad thing about it       []
#
#                      handles
# 0  [VirginAmerica, dhepburn]
# 1            [VirginAmerica]
# 2            [VirginAmerica]
# 3            [VirginAmerica]
# 4            [VirginAmerica]

# %%
df["airline_sentiment"].unique()
# Out:
# array(['neutral', 'positive', 'negative'], dtype=object)

# %% [markdown]
# ### Sentimental analysis using Textblob

# %%
analyzer = SentimentIntensityAnalyzer()

df['tb_polarity'] = df['clean_text'].apply(lambda x: TextBlob(x).polarity)
df['tb_sentiment'] = df['tb_polarity'].apply(lambda x: 'positive' if x >0 else('nuetral' if x==0 else 'negative') )

df.sample(n=10)
# Out:
#       airline_sentiment         airline  \
# 3417           negative          United
# 4429           negative       Southwest
# 9446           negative      US Airways
# 2586            neutral          United
# 9273           negative      US Airways
# 12059           neutral        American
# 7967           negative           Delta
# 6550            neutral       Southwest
# 272            positive  Virgin America
# 10290          negative      US Airways
#
#                                                     text  \
# 3417   @united whom can I call to discuss - as I was ...
# 4429   @SouthwestAir I booked a flight on my phone an...
# 9446   @USAirways flights &amp; "customer relations" ...
# 2586   @united If you'd love to see more girls be ins...
# 9273   @USAirways  has me on my toes whether I'm goin...
# 12059  @AmericanAir my flight got Cancelled Flightled...
# 7967   @JetBlue were boarding now I'm really not impr...
# 6550   @SouthwestAir employees spreading a bit of #Ma...
# 272    @VirginAmerica your inflight team makes the ex...
# 10290  @USAirways No US Air ppl anywhere in PHL direc...
#
#                                               clean_text  \
# 3417   whom can call to discuss as was told that unit...
# 4429   booked flight on my phone and then never got c...
# 9446   flights customer relations are extremely disap...
# 2586   if love to see more girls be inspired about be...
# 9273   has me on my toes whether going to make my fli...
# 12059  my flight got cancelled flightled from grk to ...
# 7967   were boarding now really not impressed learnt ...
# 6550   employees spreading bit of cheer at this morni...
# 272              your inflight team makes the experience
# 10290  no us air ppl anywhere in phl directed strande...
#
#                           hashtags          handles  tb_polarity tb_sentiment
# 3417                            []         [united]      -0.5000     negative
# 4429                            []   [SouthwestAir]       0.0000      nuetral
# 9446                            []      [USAirways]      -0.0500     negative
# 2586                            []         [united]       0.4625     positive
# 9273                            []      [USAirways]       0.0000      nuetral
# 12059                           []    [AmericanAir]       0.0000      nuetral
# 7967                            []        [JetBlue]      -0.1500     negative
# 6550   [MardiGras, NFTYConvention]   [SouthwestAir]       0.0000      nuetral
# 272                      [amazing]  [VirginAmerica]       0.0000      nuetral
# 10290                           []      [USAirways]       0.0000      nuetral

# %% [markdown]
# ### Sentimental analysis using NLTK

# %%
analyzer = SentimentIntensityAnalyzer()

df['nltk_polarity'] = df['clean_text'].apply(lambda x: analyzer.polarity_scores(x)['compound'])
df['nltk_sentiment'] = df['nltk_polarity'].apply(lambda x: 'positive' if x >0 else('nuetral' if x==0 else 'negative'))

df.sample(n=10)
# Out:
#       airline_sentiment     airline  \
# 4969            neutral   Southwest
# 13651          negative    American
# 12013          negative    American
# 5802           negative   Southwest
# 10241          negative  US Airways
# 13775          negative    American
# 4394           negative   Southwest
# 2249            neutral      United
# 10428          positive  US Airways
# 4248           negative      United
#
#                                                     text  \
# 4969   @SouthwestAir @TheAcademy party in #hotlanta h...
# 13651  @AmericanAir still waiting on a dm response......
# 12013     @AmericanAir @lpalumbo what weather sun is out
# 5802   @SouthwestAir, what do you know? Finally lined...
# 10241  @USAirways ever think about hiring more agents...
# 13775  @AmericanAir @dogbuckeye No, I was on hold for...
# 4394   @SouthwestAir @SMiles1307 over two hours now. ...
# 2249   @united I was on UA1069 today and left my sung...
# 10428                            @USAirways thank you!!!
# 4248   @united @NY_NJairports Only at Newark can you ...
#
#                                               clean_text  \
# 4969                                            party in
# 13651                       still waiting on dm response
# 12013                            what weather sun is out
# 5802   what do you know finally lined up like cattle ...
# 10241  ever think about hiring more agents come on no...
# 13775  no was on hold for hours diff agents each diff...
# 4394   over two hours now ugh we should all get vouch...
# 2249   was on today and left my sunglasses in seat pl...
# 10428                                          thank you
# 4248   only at newark can you land minutes early but ...
#
#                    hashtags                     handles  tb_polarity  \
# 4969             [hotlanta]  [SouthwestAir, TheAcademy]     0.000000
# 13651    [sloooowresponses]               [AmericanAir]     0.000000
# 12013                    []     [AmericanAir, lpalumbo]     0.000000
# 5802   [badcustomerservice]              [SouthwestAir]     0.187500
# 10241                    []                 [USAirways]    -0.006944
# 13775                    []   [AmericanAir, dogbuckeye]    -0.200000
# 4394                     []  [SouthwestAir, SMiles1307]     0.500000
# 2249       [UnitedAirlines]                    [united]     0.000000
# 10428                    []                 [USAirways]     0.000000
# 4248                     []     [united, NY_NJairports]     0.050000
#
#       tb_sentiment  nltk_polarity nltk_sentiment
# 4969       nuetral         0.4019       positive
# 13651      nuetral         0.0000        nuetral
# 12013      nuetral         0.0000        nuetral
# 5802      positive         0.5859       positive
# 10241     negative        -0.2975       negative
# 13775     negative        -0.6249       negative
# 4394      positive        -0.1531       negative
# 2249       nuetral         0.6124       positive
# 10428      nuetral         0.3612       positive
# 4248      positive        -0.5499       negative

# %%
import numpy as np
print(np.corrcoef(df.tb_polarity, df.nltk_polarity))      # Correlation
# Out:
# [[1.        0.5602282]
#  [0.5602282 1.       ]]

# %%
df[['airline_sentiment','tb_sentiment','nltk_sentiment']]
# Out:
#       airline_sentiment tb_sentiment nltk_sentiment
# 0               neutral      nuetral        nuetral
# 1              positive      nuetral        nuetral
# 2               neutral     negative        nuetral
# 3              negative     positive       negative
# 4              negative     negative       negative
# ...                 ...          ...            ...
# 14635          positive      nuetral       positive
# 14636          negative     negative       negative
# 14637           neutral      nuetral       positive
# 14638          negative     negative       positive
# 14639           neutral     positive       positive
#
# [14640 rows x 3 columns]

# %%
print(f"airline_blob_positive_words:- {df['airline_sentiment'].value_counts().get('positive', 0)}")
print(f"text_blob_positive_words:- {df['tb_sentiment'].value_counts().get('positive', 0)}")
print(f"nltk_blob_positive_words:- {df['nltk_sentiment'].value_counts().get('positive', 0)}")
print(f"airline_negative_words:- {df['airline_sentiment'].value_counts().get('negative', 0)}")
print(f"text_blob_negative_words:- {df['tb_sentiment'].value_counts().get('negative', 0)}")
print(f"nltk_negative_words:- {df['nltk_sentiment'].value_counts().get('negative', 0)}")
# Out:
# airline_blob_positive_words:- 2363
# text_blob_positive_words:- 5466
# nltk_blob_positive_words:- 6348
# airline_negative_words:- 9178
# text_blob_negative_words:- 3493
# nltk_negative_words:- 5082

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_tb = accuracy_score(df['airline_sentiment'], df['tb_sentiment'])

print(f'Accuracy of text blob: {accuracy_tb:.2f}')
# Out:
# Accuracy of text blob: 0.33

# %%
accuracy_nltk = accuracy_score(df['airline_sentiment'], df['nltk_sentiment'])

print(f'Accuracy of nltk: {accuracy_nltk:.2f}')
# Out:
# Accuracy of nltk: 0.45

# %% [markdown]
# - summary:
# From above we can see that the text blob accuracy is about 0.33 where nltk is 0.45 so from this we can say that nltk sentiment analyzer is better than textblob.
