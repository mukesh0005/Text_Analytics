# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from webdriver_manager.firefox import GeckoDriverManager
import re
import dateparser

# %%
# here we scrape information on president's term and party
# 
# NOTE: Britiania seems to be attempting to block web scrapers. When this happened, a regular requests
# approach will fail. To bypass this, you will need to use  selenium. 
# The following code should work if site is blocking scraper:

driver = webdriver.Firefox()

url = "https://www.britannica.com/topic/Presidents-of-the-United-States-1846696"
driver.get(url)
driver.implicitly_wait(10)

page_source = driver.page_source

presidents = pd.read_html(page_source)[0]
presidents.tail(20)
# Out:
#                  Unnamed: 0                      no.                president  \
# 28                      NaN                       29        Warren G. Harding
# 29                      NaN                       30          Calvin Coolidge
# 30                      NaN                       31           Herbert Hoover
# 31                      NaN                       32    Franklin D. Roosevelt
# 32                      NaN                       33          Harry S. Truman
# 33                      NaN                       34     Dwight D. Eisenhower
# 34                      NaN                       35          John F. Kennedy
# 35                      NaN                       36        Lyndon B. Johnson
# 36                      NaN                       37         Richard M. Nixon
# 37                      NaN                       38           Gerald R. Ford
# 38                      NaN                       39             Jimmy Carter
# 39                      NaN                       40            Ronald Reagan
# 40                      NaN                       41              George Bush
# 41                      NaN                       42             Bill Clinton
# 42                      NaN                       43           George W. Bush
# 43                      NaN                       44             Barack Obama
# 44                      NaN                       45             Donald Trump
# 45                      NaN                       46                Joe Biden
# 46         *Died in office.         *Died in office.         *Died in office.
# 47  **Resigned from office.  **Resigned from office.  **Resigned from office.
#
#                  birthplace          political party                     term
# 28                     Ohio               Republican                 1921–23*
# 29                      Vt.               Republican                  1923–29
# 30                     Iowa               Republican                  1929–33
# 31                     N.Y.               Democratic                 1933–45*
# 32                      Mo.               Democratic                  1945–53
# 33                    Texas               Republican                  1953–61
# 34                    Mass.               Democratic                 1961–63*
# 35                    Texas               Democratic                  1963–69
# 36                   Calif.               Republican                1969–74**
# 37                     Neb.               Republican                  1974–77
# 38                      Ga.               Democratic                  1977–81
# 39                     Ill.               Republican                  1981–89
# 40                    Mass.               Republican                  1989–93
# 41                     Ark.               Democratic                1993–2001
# 42                    Conn.               Republican                  2001–09
# 43                   Hawaii               Democratic                  2009–17
# 44                     N.Y.               Republican                  2017–21
# 45                      Pa.               Democratic                    2021–
# 46         *Died in office.         *Died in office.         *Died in office.
# 47  **Resigned from office.  **Resigned from office.  **Resigned from office.

# %%
# note that the last two rows contains non-presidential information
# let's remove these last two rows...
presidents = presidents.drop([int(len(presidents)-1), int(len(presidents)-2)])

presidents.shape
# Out:
# (46, 6)

# %%
# let's split term colunn into two columns: from and to
presidents['from'] = presidents['term'].apply(lambda x: dateparser.parse(x.split("–")[0]).year)

def to_year(row):    
    # remove all non-digit characters from s except -
    row['term'] = re.sub(r"[^\d-]", "", row['term'])
    term_list = row['term'].split("–")
    if  len(term_list)== 1:
        return row['from']
    elif len(term_list) == 2:
        return str(row['from'])[:2] + term_list[1]
    else:
        return "bad data"
    return row
    
presidents['to'] = presidents.apply(lambda row: to_year(row), axis=1)

presidents
# Out:
#    Unnamed: 0 no.               president birthplace        political party  \
# 0         NaN   1       George Washington        Va.             Federalist
# 1         NaN   2              John Adams      Mass.             Federalist
# 2         NaN   3        Thomas Jefferson        Va.  Democratic-Republican
# 3         NaN   4           James Madison        Va.  Democratic-Republican
# 4         NaN   5            James Monroe        Va.  Democratic-Republican
# 5         NaN   6       John Quincy Adams      Mass.    National Republican
# 6         NaN   7          Andrew Jackson       S.C.             Democratic
# 7         NaN   8        Martin Van Buren       N.Y.             Democratic
# 8         NaN   9  William Henry Harrison        Va.                   Whig
# 9         NaN  10              John Tyler        Va.                   Whig
# 10        NaN  11           James K. Polk       N.C.             Democratic
# 11        NaN  12          Zachary Taylor        Va.                   Whig
# 12        NaN  13        Millard Fillmore       N.Y.                   Whig
# 13        NaN  14         Franklin Pierce       N.H.             Democratic
# 14        NaN  15          James Buchanan        Pa.             Democratic
# 15        NaN  16         Abraham Lincoln        Ky.             Republican
# 16        NaN  17          Andrew Johnson       N.C.     Democratic (Union)
# 17        NaN  18        Ulysses S. Grant       Ohio             Republican
# 18        NaN  19     Rutherford B. Hayes       Ohio             Republican
# 19        NaN  20       James A. Garfield       Ohio             Republican
# 20        NaN  21       Chester A. Arthur        Vt.             Republican
# 21        NaN  22        Grover Cleveland       N.J.             Democratic
# 22        NaN  23       Benjamin Harrison       Ohio             Republican
# 23        NaN  24        Grover Cleveland       N.J.             Democratic
# 24        NaN  25        William McKinley       Ohio             Republican
# 25        NaN  26      Theodore Roosevelt       N.Y.             Republican
# 26        NaN  27     William Howard Taft       Ohio             Republican
# 27        NaN  28          Woodrow Wilson        Va.             Democratic
# 28        NaN  29       Warren G. Harding       Ohio             Republican
# 29        NaN  30         Calvin Coolidge        Vt.             Republican
# 30        NaN  31          Herbert Hoover       Iowa             Republican
# 31        NaN  32   Franklin D. Roosevelt       N.Y.             Democratic
# 32        NaN  33         Harry S. Truman        Mo.             Democratic
# 33        NaN  34    Dwight D. Eisenhower      Texas             Republican
# 34        NaN  35         John F. Kennedy      Mass.             Democratic
# 35        NaN  36       Lyndon B. Johnson      Texas             Democratic
# 36        NaN  37        Richard M. Nixon     Calif.             Republican
# 37        NaN  38          Gerald R. Ford       Neb.             Republican
# 38        NaN  39            Jimmy Carter        Ga.             Democratic
# 39        NaN  40           Ronald Reagan       Ill.             Republican
# 40        NaN  41             George Bush      Mass.             Republican
# 41        NaN  42            Bill Clinton       Ark.             Democratic
# 42        NaN  43          George W. Bush      Conn.             Republican
# 43        NaN  44            Barack Obama     Hawaii             Democratic
# 44        NaN  45            Donald Trump       N.Y.             Republican
# 45        NaN  46               Joe Biden        Pa.             Democratic
#
#           term  from    to
# 0      1789–97  1789  1789
# 1    1797–1801  1797  1797
# 2      1801–09  1801  1801
# 3      1809–17  1809  1809
# 4      1817–25  1817  1817
# 5      1825–29  1825  1825
# 6      1829–37  1829  1829
# 7      1837–41  1837  1837
# 8        1841*  1841  1841
# 9      1841–45  1841  1841
# 10     1845–49  1845  1845
# 11    1849–50*  1849  1849
# 12     1850–53  1850  1850
# 13     1853–57  1853  1853
# 14     1857–61  1857  1857
# 15    1861–65*  1861  1861
# 16     1865–69  1865  1865
# 17     1869–77  1869  1869
# 18     1877–81  1877  1877
# 19       1881*  1881  1881
# 20     1881–85  1881  1881
# 21     1885–89  1885  1885
# 22     1889–93  1889  1889
# 23     1893–97  1893  1893
# 24  1897–1901*  1897  1897
# 25     1901–09  1901  1901
# 26     1909–13  1909  1909
# 27     1913–21  1913  1913
# 28    1921–23*  1921  1921
# 29     1923–29  1923  1923
# 30     1929–33  1929  1929
# 31    1933–45*  1933  1933
# 32     1945–53  1945  1945
# 33     1953–61  1953  1953
# 34    1961–63*  1961  1961
# 35     1963–69  1963  1963
# 36   1969–74**  1969  1969
# 37     1974–77  1974  1974
# 38     1977–81  1977  1977
# 39     1981–89  1981  1981
# 40     1989–93  1989  1989
# 41   1993–2001  1993  1993
# 42     2001–09  2001  2001
# 43     2009–17  2009  2009
# 44     2017–21  2017  2017
# 45       2021–  2021  2021

# %%
presidents.to_csv("presidents.csv", encoding="utf-8",quotechar="'",index=False)

# %%
# now, let's merge speeches dataframe with presidents dataframe - since there are some slight variations in the 
# president names between these two tables, we will use a fuzzy merge technique
import difflib 

df1 = pd.read_csv("presidential_speeches.csv", encoding="utf-8",quotechar="'")
df2 = pd.read_csv("presidents.csv", encoding="utf-8",quotechar="'")

# change the column name of the presidents dataframe to match the speeches dataframe
# In the presidents dataframe, the column name is 'president'. In the speeches dataframe, the column name is 'name'
df2.rename(columns={'president':'name'}, inplace=True)

#create duplicate column to retain team name from df2
df2['name_match'] = df2['name']

#convert team name in df2 to team name it most closely matches in df1
df2['name'] = df2['name'].apply(lambda x: difflib.get_close_matches(x, df1['name'])[0])

df2
# Out:
#     Unnamed: 0  no.                   name birthplace        political party  \
# 0          NaN    1      George Washington        Va.             Federalist
# 1          NaN    2             John Adams      Mass.             Federalist
# 2          NaN    3       Thomas Jefferson        Va.  Democratic-Republican
# 3          NaN    4          James Madison        Va.  Democratic-Republican
# 4          NaN    5           James Monroe        Va.  Democratic-Republican
# 5          NaN    6      John Quincy Adams      Mass.    National Republican
# 6          NaN    7         Andrew Jackson       S.C.             Democratic
# 7          NaN    8       Martin Van Buren       N.Y.             Democratic
# 8          NaN    9       William Harrison        Va.                   Whig
# 9          NaN   10             John Tyler        Va.                   Whig
# 10         NaN   11          James K. Polk       N.C.             Democratic
# 11         NaN   12         Zachary Taylor        Va.                   Whig
# 12         NaN   13       Millard Fillmore       N.Y.                   Whig
# 13         NaN   14        Franklin Pierce       N.H.             Democratic
# 14         NaN   15         James Buchanan        Pa.             Democratic
# 15         NaN   16        Abraham Lincoln        Ky.             Republican
# 16         NaN   17         Andrew Johnson       N.C.     Democratic (Union)
# 17         NaN   18       Ulysses S. Grant       Ohio             Republican
# 18         NaN   19    Rutherford B. Hayes       Ohio             Republican
# 19         NaN   20      James A. Garfield       Ohio             Republican
# 20         NaN   21      Chester A. Arthur        Vt.             Republican
# 21         NaN   22       Grover Cleveland       N.J.             Democratic
# 22         NaN   23      Benjamin Harrison       Ohio             Republican
# 23         NaN   24       Grover Cleveland       N.J.             Democratic
# 24         NaN   25       William McKinley       Ohio             Republican
# 25         NaN   26     Theodore Roosevelt       N.Y.             Republican
# 26         NaN   27           William Taft       Ohio             Republican
# 27         NaN   28         Woodrow Wilson        Va.             Democratic
# 28         NaN   29      Warren G. Harding       Ohio             Republican
# 29         NaN   30        Calvin Coolidge        Vt.             Republican
# 30         NaN   31         Herbert Hoover       Iowa             Republican
# 31         NaN   32  Franklin D. Roosevelt       N.Y.             Democratic
# 32         NaN   33        Harry S. Truman        Mo.             Democratic
# 33         NaN   34   Dwight D. Eisenhower      Texas             Republican
# 34         NaN   35        John F. Kennedy      Mass.             Democratic
# 35         NaN   36      Lyndon B. Johnson      Texas             Democratic
# 36         NaN   37       Richard M. Nixon     Calif.             Republican
# 37         NaN   38            Gerald Ford       Neb.             Republican
# 38         NaN   39           Jimmy Carter        Ga.             Democratic
# 39         NaN   40          Ronald Reagan       Ill.             Republican
# 40         NaN   41         George W. Bush      Mass.             Republican
# 41         NaN   42           Bill Clinton       Ark.             Democratic
# 42         NaN   43         George W. Bush      Conn.             Republican
# 43         NaN   44           Barack Obama     Hawaii             Democratic
# 44         NaN   45           Donald Trump       N.Y.             Republican
# 45         NaN   46              Joe Biden        Pa.             Democratic
#
#           term  from    to              name_match
# 0      1789–97  1789  1789       George Washington
# 1    1797–1801  1797  1797              John Adams
# 2      1801–09  1801  1801        Thomas Jefferson
# 3      1809–17  1809  1809           James Madison
# 4      1817–25  1817  1817            James Monroe
# 5      1825–29  1825  1825       John Quincy Adams
# 6      1829–37  1829  1829          Andrew Jackson
# 7      1837–41  1837  1837        Martin Van Buren
# 8        1841*  1841  1841  William Henry Harrison
# 9      1841–45  1841  1841              John Tyler
# 10     1845–49  1845  1845           James K. Polk
# 11    1849–50*  1849  1849          Zachary Taylor
# 12     1850–53  1850  1850        Millard Fillmore
# 13     1853–57  1853  1853         Franklin Pierce
# 14     1857–61  1857  1857          James Buchanan
# 15    1861–65*  1861  1861         Abraham Lincoln
# 16     1865–69  1865  1865          Andrew Johnson
# 17     1869–77  1869  1869        Ulysses S. Grant
# 18     1877–81  1877  1877     Rutherford B. Hayes
# 19       1881*  1881  1881       James A. Garfield
# 20     1881–85  1881  1881       Chester A. Arthur
# 21     1885–89  1885  1885        Grover Cleveland
# 22     1889–93  1889  1889       Benjamin Harrison
# 23     1893–97  1893  1893        Grover Cleveland
# 24  1897–1901*  1897  1897        William McKinley
# 25     1901–09  1901  1901      Theodore Roosevelt
# 26     1909–13  1909  1909     William Howard Taft
# 27     1913–21  1913  1913          Woodrow Wilson
# 28    1921–23*  1921  1921       Warren G. Harding
# 29     1923–29  1923  1923         Calvin Coolidge
# 30     1929–33  1929  1929          Herbert Hoover
# 31    1933–45*  1933  1933   Franklin D. Roosevelt
# 32     1945–53  1945  1945         Harry S. Truman
# 33     1953–61  1953  1953    Dwight D. Eisenhower
# 34    1961–63*  1961  1961         John F. Kennedy
# 35     1963–69  1963  1963       Lyndon B. Johnson
# 36   1969–74**  1969  1969        Richard M. Nixon
# 37     1974–77  1974  1974          Gerald R. Ford
# 38     1977–81  1977  1977            Jimmy Carter
# 39     1981–89  1981  1981           Ronald Reagan
# 40     1989–93  1989  1989             George Bush
# 41   1993–2001  1993  1993            Bill Clinton
# 42     2001–09  2001  2001          George W. Bush
# 43     2009–17  2009  2009            Barack Obama
# 44     2017–21  2017  2017            Donald Trump
# 45       2021–  2021  2021               Joe Biden

# %%
#merge the DataFrames into one
df3 = df1.merge(df2)

#view final DataFrame
df3
# Out:
#                    name                                              title  \
# 0             Joe Biden  February 21, 2023: Remarks on the One-Year Ann...
# 1             Joe Biden       February 7, 2023: State of the Union Address
# 2             Joe Biden  September 21, 2022: Speech before the 77th Ses...
# 3             Joe Biden  September 1, 2022: Remarks on the Continued Ba...
# 4             Joe Biden  May 24, 2022: Remarks on School Shooting in Uv...
# ...                 ...                                                ...
# 1086  George Washington  December 29, 1790: Talk to the Chiefs and Coun...
# 1087  George Washington  December 8, 1790: Second Annual Message to Con...
# 1088  George Washington  January 8, 1790: First Annual Message to Congress
# 1089  George Washington         October 3, 1789: Thanksgiving Proclamation
# 1090  George Washington            April 30, 1789: First Inaugural Address
#
#             date                                               info  \
# 0     2023-02-21  Speaking at the Royal Castle in Warsaw, Poland...
# 1     2023-02-07  In his State of the Union Address, President J...
# 2     2022-09-21  President Joe Biden addresses the 77th session...
# 3     2022-09-01  President Joe Biden speaks in Philadelphia, Pe...
# 4     2022-05-24  President Biden makes an impassioned plea to s...
# ...          ...                                                ...
# 1086  1790-12-29  The President reassures the Seneca Nation that...
# 1087  1790-12-08  Washington focuses on commerce in his second a...
# 1088  1790-01-08  In a wide-ranging speech, President Washington...
# 1089  1789-10-03  At the request of Congress, Washington establi...
# 1090  1789-04-30  President George Washington calls on Congress ...
#
#                                                  speech  Unnamed: 0  no.  \
# 0        THE PRESIDENT:  Hello, Poland! One of our g...         NaN   46
# 1        Mr.  Speaker.  Madam Vice President.  Our F...         NaN   46
# 2        Thank you.   Mr.  President, Mr.  Secretary...         NaN   46
# 3        THE PRESIDENT: My fellow Americans, please,...         NaN   46
# 4        Good evening, fellow Americans.  I had hope...         NaN   46
# ...                                                 ...         ...  ...
# 1086    I the President of the United States, by my ...         NaN    1
# 1087    Fellow citizens of the Senate and House of R...         NaN    1
# 1088   Fellow Citizens of the Senate and House of Re...         NaN    1
# 1089   Whereas it is the duty of all Nations to ackn...         NaN    1
# 1090   Fellow Citizens of the Senate and the House o...         NaN    1
#
#      birthplace political party     term  from    to         name_match
# 0           Pa.      Democratic    2021–  2021  2021          Joe Biden
# 1           Pa.      Democratic    2021–  2021  2021          Joe Biden
# 2           Pa.      Democratic    2021–  2021  2021          Joe Biden
# 3           Pa.      Democratic    2021–  2021  2021          Joe Biden
# 4           Pa.      Democratic    2021–  2021  2021          Joe Biden
# ...         ...             ...      ...   ...   ...                ...
# 1086        Va.      Federalist  1789–97  1789  1789  George Washington
# 1087        Va.      Federalist  1789–97  1789  1789  George Washington
# 1088        Va.      Federalist  1789–97  1789  1789  George Washington
# 1089        Va.      Federalist  1789–97  1789  1789  George Washington
# 1090        Va.      Federalist  1789–97  1789  1789  George Washington
#
# [1091 rows x 13 columns]

# %%
df3.to_csv("presidential_speeches.csv", encoding="utf-8",quotechar="'",index=False)

# %%
df3['political party'].value_counts()
# Out:
# political party
# Democratic               497
# Republican               439
# Democratic-Republican     56
# Democratic (Union)        31
# Whig                      30
# Federalist                30
# National Republican        8
# Name: count, dtype: int64
