# %% [markdown]
# ## Airline Tweets: Sentiment Analysis & Simple Classification
#
# ### ISM6564
#
# **Week04, Part02**
#
# &copy; 2023 Dr. Tim Smith
#
# <a target="_blank" href="https://colab.research.google.com/github/prof-tcsmith/ta-f23/blob/main/W04/4.3-Tutorial - Descriptive Analysis - brand sentiment.ipynb#offline=1">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# ---

# %% [markdown]
# ## Introduction
#
# In this notebook we will analysze the sentiment from a dataset on how travelers tweeted about their airline-related feelings, scraped from Twitter in February 2015;.

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (2023.8.8)
# Requirement already satisfied: tqdm in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (4.66.1)
# Requirement already satisfied: colorama in c:\users\veera\appdata\roaming\python\python311\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\veera\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\veera\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\veera\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from matplotlib import pyplot as plt

from nltk.tokenize import TweetTokenizer

from nltk.sentiment.vader import SentimentIntensityAnalyzer

from textblob import TextBlob
import seaborn as sns

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# read in the data 
df = pd.read_csv('data/Tweets.csv') 
df.head()
# Out:
#        tweet_id         airline        name  retweet_count  \
# 0  5.703060e+17  Virgin America     cairdin              0
# 1  5.703010e+17  Virgin America    jnardino              0
# 2  5.703010e+17  Virgin America  yvonnalynn              0
# 3  5.703010e+17  Virgin America    jnardino              0
# 4  5.703010e+17  Virgin America    jnardino              0
#
#                                                 text
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...

# %%
tokenizer = TweetTokenizer()

def clear_text(text):
    # tokenize the text
    # nltk.download('punkt') # uncomment if you need to download the punkt package
    tokens = tokenizer.tokenize(text)
    
    # remove all tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    
    # make lowercase
    tokens = [word.lower() for word in tokens]

    # remove all tokens that are only one character
    tokens = [word for word in tokens if len(word) > 1]

    return ' '.join(tokens)

df['clean_text']=df.text.apply(lambda x: clear_text(x))   
df['hashtags'] = df.text.apply(lambda text: re.findall(r"#(\w+)", text))
df['handles'] = df.text.apply(lambda text: re.findall(r"@(\w+)", text))

# %%
df.head(10)
# Out:
#        tweet_id         airline        name  retweet_count  \
# 0  5.703060e+17  Virgin America     cairdin              0
# 1  5.703010e+17  Virgin America    jnardino              0
# 2  5.703010e+17  Virgin America  yvonnalynn              0
# 3  5.703010e+17  Virgin America    jnardino              0
# 4  5.703010e+17  Virgin America    jnardino              0
# 5  5.703010e+17  Virgin America    jnardino              0
# 6  5.703010e+17  Virgin America  cjmcginnis              0
# 7  5.703000e+17  Virgin America       pilot              0
# 8  5.703000e+17  Virgin America    dhepburn              0
# 9  5.702950e+17  Virgin America  YupitsTate              0
#
#                                                 text  \
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...
# 5  @VirginAmerica seriously would pay $30 a fligh...
# 6  @VirginAmerica yes, nearly every time I fly VX...
# 7  @VirginAmerica Really missed a prime opportuni...
# 8    @virginamerica Well, I didn't…but NOW I DO! :-D
# 9  @VirginAmerica it was amazing, and arrived an ...
#
#                                           clean_text hashtags  \
# 0                                          what said       []
# 1     plus added commercials to the experience tacky       []
# 2          today must mean need to take another trip       []
# 3  really aggressive to blast obnoxious entertain...       []
# 4                  and really big bad thing about it       []
# 5  seriously would pay flight for seats that have...       []
# 6  yes nearly every time fly vx this ear worm won...       []
# 7  really missed prime opportunity for men withou...       []
# 8                                    well but now do       []
# 9  it was amazing and arrived an hour early too g...       []
#
#                      handles
# 0  [VirginAmerica, dhepburn]
# 1            [VirginAmerica]
# 2            [VirginAmerica]
# 3            [VirginAmerica]
# 4            [VirginAmerica]
# 5            [VirginAmerica]
# 6            [VirginAmerica]
# 7            [VirginAmerica]
# 8            [virginamerica]
# 9            [VirginAmerica]

# %%
df = df.drop(columns=["tweet_id", "name", "retweet_count"]) # though we could use these columns for other analysis, for this analysis we will not

# %%
df.columns
# Out:
# Index(['airline', 'text', 'clean_text', 'hashtags', 'handles'], dtype='object')

# %%
df["airline"].unique()
# Out:
# array(['Virgin America', 'United', 'Southwest', 'Delta', 'US Airways',
#        'American'], dtype=object)

# %% [markdown]
# ### Sentiment analysis using TextBlob

# %%
analyzer = SentimentIntensityAnalyzer()

df['tb_polarity'] = df['clean_text'].apply(lambda x: TextBlob(x).polarity)
df['tb_sentiment'] = df['tb_polarity'].apply(lambda x: 'pos' if x >=0 else 'neg')

df.sample(n=20)
# Out:
#           airline                                               text  \
# 12542    American  @AmericanAir and btwn gate a8 &amp; a15 I lost...
# 9992   US Airways  @USAirways now after an hour on the plane and ...
# 13235    American  @AmericanAir Retrain in Customer Service first...
# 7826        Delta  @JetBlue where did my travel bank credit go?  ...
# 11244  US Airways  @USAirways you're the only airline that's not ...
# 7583        Delta  @JetBlue That's not what I heard. Weather was ...
# 7133        Delta  “@JetBlue: Our fleet's on fleek. http://t.co/J...
# 11157  US Airways  “@USAirways: Reminder: From 2/28, we’ll be twe...
# 976        United  @united first time flying with United. Also la...
# 2321       United  @united cabin crew were huge offenders, stood ...
# 9781   US Airways  @USAirways so I guess you are ok with people b...
# 3182       United  @united sent you my confirmation via DM. Thank...
# 10621  US Airways  @USAirways incapable of seating a 2yo and mom ...
# 13859    American  @AmericanAir wow @AmericanAir still screw n st...
# 12257    American  @AmericanAir \nCan you tell me what that means...
# 3388       United  @united even so, change could not be made  onl...
# 7129        Delta               @JetBlue @courteroy LOLZ. "On Fleek"
# 8553        Delta  @JetBlue just DMed. thanks so much for address...
# 5966    Southwest  @SouthwestAir wouldn't it be awesome for my fi...
# 14242    American     @AmericanAir Now your site is not working! WTF
#
#                                               clean_text  \
# 12542  and btwn gate lost diamond earring pls have ma...
# 9992   now after an hour on the plane and knowing of ...
# 13235  retrain in customer service first make proper ...
# 7826   where did my travel bank credit go call you ri...
# 11244  the only airline not open sooner not confidenc...
# 7583   not what heard weather was fine this morning f...
# 7133             our on fleek jet blizzue in the hizouse
# 11157  reminder from we ll be tweeting from you shoul...
# 976    first time flying with united also last time b...
# 2321   cabin crew were huge offenders stood as conver...
# 9781   so guess you are ok with people being sexually...
# 3182   sent you my confirmation via dm thank you very...
# 10621  incapable of seating and mom together toddler ...
# 13859                           wow still screw stuff up
# 12257  can you tell me what that means work and just ...
# 3388   even so change could not be made online instru...
# 7129                                       lolz on fleek
# 8553   just dmed thanks so much for addressing this s...
# 5966        it be awesome for my first time flying to be
# 14242                   now your site is not working wtf
#
#                                                 hashtags  \
# 12542                                  [dayjustgotWORSE]
# 9992                                                  []
# 13235                                                 []
# 7826                                                  []
# 11244                                                 []
# 7583                                                  []
# 7133                                                  []
# 11157                                                 []
# 976    [terrible, branson, virginatlantic, UnitedAirl...
# 2321                                                  []
# 9781                                                  []
# 3182                                                  []
# 10621                                             [fail]
# 13859                                                 []
# 12257                                                 []
# 3388                                                  []
# 7129                                                  []
# 8553                                                  []
# 5966                                [DestinationDragons]
# 14242                                                 []
#
#                           handles  tb_polarity tb_sentiment
# 12542               [AmericanAir]     0.000000          pos
# 9992                  [USAirways]     0.000000          pos
# 13235               [AmericanAir]     0.283333          pos
# 7826                    [JetBlue]     0.285714          pos
# 11244                 [USAirways]     0.000000          pos
# 7583                    [JetBlue]     0.391667          pos
# 7133                    [JetBlue]     0.000000          pos
# 11157    [USAirways, AmericanAir]     0.000000          pos
# 976      [united, VirginAtlantic]     0.083333          pos
# 2321                     [united]     0.400000          pos
# 9781                  [USAirways]     0.533333          pos
# 3182                     [united]     0.260000          pos
# 10621            [USAirways, CNN]     0.600000          pos
# 13859  [AmericanAir, AmericanAir]     0.100000          pos
# 12257               [AmericanAir]     0.200000          pos
# 3388                     [united]     0.000000          pos
# 7129         [JetBlue, courteroy]     0.000000          pos
# 8553                    [JetBlue]     0.244444          pos
# 5966               [SouthwestAir]     0.625000          pos
# 14242               [AmericanAir]    -0.500000          neg

# %%
df.loc[df.tb_polarity >= 0.85 , ["tb_polarity", "airline", "text"]].sample(20).values
# Out:
# array([[1.0, 'Delta', '@JetBlue awesome'],
#        [0.89, 'American',
#         "@AmericanAir Agents in DFW were very kind did their best to help, but this doesn't make up for PHX error and attitude! #Americant"],
#        [1.0, 'United',
#         '@united I do I was on UA 495 LAX TO DEN - we are scheduled to land LAX @ 7:38 am - please rebook to Denver - best flight'],
#        [1.0, 'Virgin America',
#         '@VirginAmerica husband and I ordered three drinks via my screen and they never came. Awesome!'],
#        [1.0, 'American',
#         "@americanair the best is your 800 message saying to use website and your website is saying you need to call.  If you don't answer, #hardtodo"],
#        [1.0, 'Southwest',
#         '@SouthwestAir @JasonWhitely flt 947 Emer stop in Albuquer for a heart condition, crew was awesome, pilot was Maverick on the divert.'],
#        [1.0, 'Virgin America',
#         '@VirginAmerica called your service line and was hung up on. This is awesome. #sarcasm'],
#        [1.0, 'US Airways',
#         '@USAirways Ann Marie at LGA is the best ticket agent ever! #excellentcustomerservice'],
#        [0.85, 'Southwest',
#         '@SouthwestAir beautiful view flying into San Jose, CA this evening http://t.co/SxVaGbRTlI'],
#        [0.9, 'Delta',
#         '@JetBlue Thank you guys! Brilliant customer service'],
#        [1.0, 'Southwest',
#         '@SouthwestAir It was the usually excellent SWA flight!'],
#        [1.0, 'Delta',
#         '@JetBlue thank you will do!! You guy are awesome!'],
#        [0.85, 'American',
#         '@AmericanAir 1) I was on 1610 today to YYZ. I had a bit of a bag issue that was cleared up beautifully. Thank you to all of the check in'],
#        [1.0, 'Southwest',
#         '@SouthwestAir @FortuneMagazine Superb choice - SWA. I am a raving fan. They even take stress out of weather-reLate Flightd glitches!  #custexp'],
#        [0.9, 'Virgin America',
#         '@VirginAmerica just got on the 1pm in Newark home to LA. Your folks at EWR are incredible #letsgohome'],
#        [0.8833333333333334, 'Southwest',
#         '@SouthwestAir has a beautiful fleet. What a perfect evening to fly! http://t.co/XMZ3Tf9Ix8'],
#        [1.0, 'US Airways',
#         '@USAirways she will be reaching out to you! HARDWORKING mom just trying to do her best!'],
#        [1.0, 'United',
#         '@united he is so excellent and so reliable :) #happycustomer'],
#        [0.9099999999999999, 'United',
#         '@united Very good flight, thank you!'],
#        [1.0, 'United',
#         '@united and the fact that we were treated disrespectfully and lied to by members of your airline that claims to strive for the best']],
#       dtype=object)

# %%
df.loc[df.tb_polarity >= -0.85 , ["tb_polarity", "airline", "text"]].sample(20).values
# Out:
# array([[0.029365079365079344, 'US Airways',
#         '@USAirways if a passenger is to large to put down the armrest and now is using part of my seat, what is my recourse?  #nothappy'],
#        [0.05, 'United',
#         "@united terminal at MIA should have food open before 5am esp when there are flights at 6am. Two hours early like recommended. Can't eat."],
#        [0.1, 'Southwest',
#         '@SouthwestAir sent. looking for that functionality in your app, though. should be a one click action.'],
#        [0.0, 'US Airways', '@USAirways it takes a month?'],
#        [0.0, 'United',
#         '@united 4 open seats in 1st class on UA 2065. Way to honor your upgrade policy for freq flyers and/or honor an employee with an upgrade.'],
#        [0.2857142857142857, 'United',
#         '.@united Our newest delay, right now http://t.co/96fTLZWtvO'],
#        [-0.008333333333333331, 'United',
#         "@united wont transfer flight ticket to accompany an 11 yr old who's active military mom had to have emergency brain surgery? WOW!!"],
#        [0.0, 'United',
#         '@United - routing a person from Houston to Newark, NJ  and then to SFO is not acceptable.'],
#        [0.0, 'United',
#         "@united but if i tweet the ID number, won't that reveal my home address to anyone on the web?"],
#        [0.7, 'Southwest',
#         '@SouthwestAir good to know NOW!  Three sets of travelers in just 20 mins standing here waiting for mins to pass by.'],
#        [-0.1, 'Southwest',
#         "@SouthwestAir - thanks for Cancelled Flighting our flight to BOS. We're stranded in DEN til Wed night. The 7 of us will never fly #southwest again"],
#        [0.4, 'American',
#         '@AmericanAir Considering it was purchased on the 21st and I attempted to use it again on the 21st I believe it would fit these parameters.'],
#        [0.0, 'US Airways',
#         "@USAirways @PHLAirport how can a plane scheduled to come in on time and actually happen. Then you bozos don't have any room us. #incompetent"],
#        [0.0, 'Delta',
#         '@JetBlue Accepting #Apple Pay - Mobile Enterprise http://t.co/Ci5cfrlqBe'],
#        [0.0, 'American', '@AmericanAir check your DM please'],
#        [-0.5, 'United',
#         "@united DEN-PHX flight tomorrow Cancelled Flighted. Asked for overnight 2nite in LAX/SNA. Told not without paying. That's wrong"],
#        [0.3333333333333333, 'Southwest',
#         '@SouthwestAir give us some more clever advertising about #bagsflyfree is that because #badpolicy allows you to #cheatcustomers'],
#        [-0.3121428571428571, 'American',
#         "@AmericanAir I'm at the airport right now and your people didn't know how to react and help me with this situation. Very frustrated."],
#        [0.0, 'US Airways',
#         '@USAirways on hold for 2+ hours.. Can I book using a Take Flight voucher online??'],
#        [0.1, 'United',
#         '@united giving up on your direct flight from IAH to Honolulu. 3rd attempt in 3 years - 3rd delay.  $7 meal voucher. Wow. Customer service!']],
#       dtype=object)

# %% [markdown]
# ### Sentiment analysis using NLTK

# %%
analyzer = SentimentIntensityAnalyzer()

df['nltk_polarity'] = df['clean_text'].apply(lambda x: analyzer.polarity_scores(x)['compound'])
df['nltk_sentiment'] = df['nltk_polarity'].apply(lambda x: 'pos' if x >=0 else 'neg')

df.sample(n=20)
# Out:
#           airline                                               text  \
# 4483    Southwest  @SouthwestAir can you tell me why you Cancelle...
# 12163    American  Just got off the phone @AmericanAir customer s...
# 6501    Southwest  @SouthwestAir can you make a premium wifi that...
# 12228    American      @AmericanAir um. down south has snow too #ATL
# 11059  US Airways  @UsAirways  your person taking tickets is rude...
# 8823        Delta  @JetBlue flight 894, first officer not even at...
# 7750        Delta  @JetBlue lipstick on a pig still a pig. Ur new...
# 9096   US Airways  @USAirways oh I got right through to an agent....
# 5073    Southwest  @SouthwestAir been on hold for 1.5 hrs. What's...
# 5260    Southwest  @SouthwestAir no. Told to call cust service on...
# 2644       United        @united Sure.  Follow for a sec and I will.
# 4114       United  @united Does the economy plus cabin also quali...
# 1235       United               @united Thank you for your response!
# 14073    American  @AmericanAir that's ok, thanks for letting me ...
# 6128    Southwest  @SouthwestAir I understand weather is not your...
# 5549    Southwest  @SouthwestAir are you guys alive? i've been on...
# 8161        Delta  @JetBlue - Yes. Best case scenario I get my ge...
# 4209       United  @united flt 4567 has had two more updates in t...
# 8861        Delta  @JetBlue This could be the beginning of a BLUE...
# 7851        Delta  @JetBlue the you above all commercials? Like t...
#
#                                               clean_text             hashtags  \
# 4483   can you tell me why you cancelled flightled th...                   []
# 12163  just got off the phone customer service only m...                   []
# 6501   can you make premium wifi that can pay for tha...               [slow]
# 12228                         um down south has snow too                [ATL]
# 11059  your person taking tickets is rude and now we ...                [500]
# 8823   flight first officer not even at the airport w...                   []
# 7750   lipstick on pig still pig ur new baggage claim...               [fail]
# 9096   oh got right through to an agent they just kep...                   []
# 5073                             been on hold for hrs up                   []
# 5260              no told to call cust service on monday                   []
# 2644                        sure follow for sec and will                   []
# 4114   does the economy plus cabin also qualifies as ...                   []
# 1235                         thank you for your response                   []
# 14073  ok thanks for letting me know appreciate all t...                   []
# 6128   understand weather is not your fault but as fr...                   []
# 5549   are you guys alive been on hold for minutes an...                   []
# 8161   yes best case scenario get my gear late flight...   [toolittletooLate]
# 4209    flt has had two more updates in the last minutes                   []
# 8861   this could be the beginning of bluetiful relat...  [lifeneedsfrosting]
# 7851   the you above all commercials like the legroom...                   []
#
#                      handles  tb_polarity tb_sentiment  nltk_polarity  \
# 4483          [SouthwestAir]     0.000000          pos        -0.5106
# 12163          [AmericanAir]     0.500000          pos         0.6249
# 6501          [SouthwestAir]     0.166667          pos        -0.1027
# 12228          [AmericanAir]    -0.155556          neg         0.0000
# 11059            [UsAirways]    -0.300000          neg        -0.5994
# 8823               [JetBlue]     0.175000          pos         0.4404
# 7750               [JetBlue]     0.136364          pos        -0.7430
# 9096             [USAirways]     0.285714          pos        -0.4019
# 5073          [SouthwestAir]     0.000000          pos         0.0000
# 5260          [SouthwestAir]     0.000000          pos        -0.2960
# 2644                [united]     0.200000          pos         0.3182
# 4114                [united]     0.000000          pos         0.0000
# 1235                [united]     0.000000          pos         0.3612
# 14073          [AmericanAir]     0.350000          pos         0.7783
# 6128   [SouthwestAir, Delta]     0.166667          pos         0.6683
# 5549          [SouthwestAir]     0.100000          pos         0.3818
# 8161               [JetBlue]     0.266667          pos         0.7845
# 4209                [united]     0.250000          pos         0.0000
# 8861               [JetBlue]     0.000000          pos         0.0000
# 7851               [JetBlue]     0.000000          pos         0.3612
#
#       nltk_sentiment
# 4483             neg
# 12163            pos
# 6501             neg
# 12228            pos
# 11059            neg
# 8823             pos
# 7750             neg
# 9096             neg
# 5073             pos
# 5260             neg
# 2644             pos
# 4114             pos
# 1235             pos
# 14073            pos
# 6128             pos
# 5549             pos
# 8161             pos
# 4209             pos
# 8861             pos
# 7851             pos

# %%
df.loc[df.nltk_polarity > .85 , ["nltk_polarity", "airline", "text"]].sample(20).values
# Out:
# array([[0.8885, 'Virgin America',
#         "@VirginAmerica gave a credit for my Late Flight flight yesterday. Great service !!!! That's a Wow moment! Unexpected gesture!"],
#        [0.8993, 'United',
#         "@united If you'd love to see more girls be inspired about becoming pilots, RT our free WOAW event March 2-8 at ABQ. http://t.co/rfXlV1kGDh"],
#        [0.9001, 'Delta',
#         '“@JetBlue: @2littlebirds Well captured, Brittany! We love the clouds! :)  Enjoy the ride!” Thank you!'],
#        [0.9143, 'Southwest',
#         '@SouthwestAir Travel agent Darrel here at Love Field hosting a paper airplane contest to entertain all the children was so awesome to see!'],
#        [0.9169, 'Delta',
#         '@JetBlue I just wanted to say flight attendant fitz was the best tonight on flight #1326 bwi/Bos. Great guy and made the flight fantastic!'],
#        [0.91, 'Delta',
#         '@JetBlue OH YEAH!!! great flight down to Mexico with a wonderful crew!! Thank you!!'],
#        [0.8689, 'American',
#         '@AmericanAir These are some awesome photos. Thanks for sharing! 😁'],
#        [0.9052, 'Southwest',
#         "@SouthwestAir Flight 3056. Only an hour long but one of the best flights I've ever had. Kudos to flight crew and airline in general."],
#        [0.8519, 'Delta',
#         '@JetBlue mint seats are AWESOME! :-) @emaleesugano best business class in the US!!!'],
#        [0.9022, 'United',
#         '@united Joni did a great job on flight 5653 to LAX. Thanks for a great flight.'],
#        [0.8519, 'Virgin America',
#         '@VirginAmerica when are you putting some great deals from PDX to LAS or from LAS to PDX show me your love! http://t.co/enIQg0buzj'],
#        [0.9001, 'American',
#         "@AmericanAir excellent!  Love you guys!  If it is first class I'll hug ya'll!  See you shortly!"],
#        [0.872, 'American',
#         "@AmericanAir I'm great thanks keep up the good work"],
#        [0.8591, 'United',
#         '@united I just want shout out a thank the pilots and staff on the Feb 13 flight from Newark to Boston at 4:40pm.  They were super helpful!'],
#        [0.9081, 'United',
#         '@united pleasantly surprised with quality of service and flight.Flew LGA-CLE-DEN. Friendly crew. Love the concept of #byod #worksnicely'],
#        [0.8519, 'United',
#         '@united thanks. Just got on a couple of minutes ago. Great service on flight 479 btw. Please pass it to the team on that flight.'],
#        [0.8834, 'United',
#         '@united Both flights went great and improved my view of your airline, cheers! Flight attendents on UA1022 deserve a raise'],
#        [0.875, 'Virgin America',
#         "@VirginAmerica you have the absolute best team and customer service ever.  Every time I fly with you I'm delighted.  Thank you!"],
#        [0.8674, 'American',
#         "@AmericanAir thank you...I know it's a busy for you today but any help would be appreciated..."],
#        [0.9042, 'United',
#         "@United is the best way to re-unite me with my one true love, shopping in USA's fashion capital #NewYork #unitedVUSA http://t.co/rBn7StUij1"]],
#       dtype=object)

# %%
df.loc[df.nltk_polarity < -0.85 , ["nltk_polarity", "airline", "text"]].sample(20).values
# Out:
# array([[-0.9469, 'American',
#         "@AmericanAir but seriously if my cats dead I'm going to be pissed/very thankful because it is evil and wants my soul"],
#        [-0.9217, 'United',
#         '@united Once again I am victim to the scam that is your SHIT Customer Service, this time the agent hung up on me WTF do you teach your staff'],
#        [-0.8705, 'Southwest',
#         '@SouthwestAir#4569 Cancelled Flightled, had to get refund. Cancelled Flightlations happen. But the 25+ min phone wait &amp; painful music unacceptable. Come on...'],
#        [-0.8519, 'United',
#         '@united I tried but no one was available in bogota and everyone was rude in Houston. I was stuck for 35 hours because of you guys'],
#        [-0.9246, 'American',
#         '@AmericanAir Miami-PhL flight Cancelled Flightled just as I got to the gate. No one from AA around, no one on the phone. Awful awful awful.'],
#        [-0.894, 'United',
#         '@united, last week shanghai to sfo 858 delay 5hrs bc of engine. today sfo-sea delay to "sick pilot". no compensation. They Do. Not. Care.'],
#        [-0.8807, 'American',
#         '@AmericanAir WORST SERVICE EVER!! Delayed flights for more than 5 hours plus you missed my bag! And your employees are rude 😡😡'],
#        [-0.9153, 'Southwest',
#         '@SouthwestAir Cancelled Flightled all flights Fort Lauderdale to Philly. USAir flights got to Philly with no problem. WTF is wrong with SW @USAirways'],
#        [-0.8655, 'US Airways',
#         "@USAirways so mad I can't even believe  you guys Cancelled Flight my connecting flight after I leave the first stop, &amp; give me a useless hotel voucher"],
#        [-0.8932, 'United',
#         '@united you really screwed up dealing mechanical failure from Maui to San Francisco. Poor communication bad help in getting connections'],
#        [-0.8702, 'Delta',
#         "@JetBlue  thanks for response! Crew has been VERY patient with us, but they are also frustrated. Wouldn't be so bad but airport is closed!"],
#        [-0.8689, 'United',
#         '@united has the worst flight attendants. They are like those angry and drunk aunts that we all have. Everything has to be an argument.'],
#        [-0.9136, 'United',
#         "@united I'm saying I made the flight but with poor/non-communication, unaccounted for lost time &amp; lots of frustrated flyers standing around"],
#        [-0.8779, 'US Airways',
#         '@USAirways worst customer service. Still not providing me an answer even after I drove back to CLT airport. been rude &amp; unacceptable #fail'],
#        [-0.8898, 'American',
#         "@AmericanAir got call saying flight Cancelled Flightled but checked online and it isn't Cancelled Flightled. No where near bad weather. I have job interview"],
#        [-0.8515, 'US Airways',
#         '@USAirways that is actually not true! You can get a seat online after a big hassle. That policy is totally dishonest and misleading. #FAA'],
#        [-0.8779, 'US Airways',
#         '@USAirways he is 8 months old and is suffering from a rare form of cancer. Your customer service agents had no compassion and I am disgusted'],
#        [-0.872, 'United',
#         "@united no chance in hell. I'd rather walk. Worst airline ever."],
#        [-0.8735, 'US Airways',
#         "@USAirways I've been on hold for 36 mins and counting cause you charged my credit card for bag but provided no receipt and said error. Awful"],
#        [-0.875, 'US Airways',
#         "@USAirways this is got to be the worst service I've ever seen with an airline. 3 Cancelled Flightled flights. Rude employees. Currently flight delayed"]],
#       dtype=object)

# %% [markdown]
# ## How correlated are the polarity scores between TextBlob and NTLK?

# %%
import numpy as np
print(np.corrcoef(df.tb_polarity, df.nltk_polarity))      # Correlation
# Out:
# [[1.        0.5602282]
#  [0.5602282 1.       ]]

# %%
# Question: Which sentiment analysis is more accurate: NLTK or Textblob?
# Try sentiment analysis using other packages such as Gensim (https://radimrehurek.com/gensim/)

# %% [markdown]
# ### Data visualizations using seaborn

# %%
airlines_of_interest = ["United", "Southwest", "American"]
#data = df[df.tb_polarity != 0]
data = df[(df.tb_polarity < -0.1) | (df.tb_polarity > 0.1)]
data = data.loc[df.airline.isin(airlines_of_interest)]

print("United", df.airline[df.airline == 'United'].count())
print("Southwst", df.airline[df.airline == 'Southwest'].count())
print("American", df.airline[df.airline == 'American'].count())
# Out:
# United 3822
# Southwst 2420
# American 2759

# %%
fig, ax = plt.subplots()
ax.legend().set_title("SOMETHING")

#sns.kdeplot(data=data, x="polarity", hue="airline", multiple="stack")

#sns.histplot(data=data, x="tb_polarity", hue="airline", multiple="stack", kde=True)
#sns.histplot(data=data, x="tb_polarity", hue="airline", multiple="stack", element='step', kde=True)
#sns.histplot(data=data, x="tb_polarity", hue="airline", multiple="stack", element='step', stat="density", common_norm=False, cumulative=True, kde=True)
sns.histplot(data=data, x="tb_polarity", hue="airline", multiple="stack", element='step', kde=True)
#sns.histplot(data=data, x="tb_polarity", hue="airline", multiple="stack", element='poly', kde=True)
#sns.histplot(data=data, x="tb_polarity", hue="airline", multiple="fill", kde=True)
#sns.histplot(data=data, x="tb_polarity", hue="airline", multiple="layer", kde=True)

#sns.histplot(data=data, x="tb_polarity", hue="airline", multiple="dodge", kde=True)


plt.title("Sentiment Polarity of Two Airlines")
plt.ylabel("Tweet Count")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# You can also check out the Plot.ly graphics library - it has the ability to add sliders, and other interactive elements, to your charts
